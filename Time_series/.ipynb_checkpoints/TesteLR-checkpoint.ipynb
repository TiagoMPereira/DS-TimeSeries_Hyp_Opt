# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import datetime

# %matplotlib inline

# %%
#importando dataset de consumo de cerveja
df = pd.read_csv('Datasets/beer.csv')

#Removendo registro do mês
df['Month'] = pd.to_datetime(df['Month'])
df = df.set_index(df['Month'])
df = df.drop(columns=['Month'])

#renomeando coluna "Monthly beer production"
df = df.rename(columns={'Monthly beer production':'Beer'})

df.head()
# Out:
#             Beer
# Month
# 1956-01-01  93.2
# 1956-02-01  96.0
# 1956-03-01  95.2
# 1956-04-01  77.1
# 1956-05-01  70.9

# %% [markdown]
# ### Visualizando dataset

# %%
plt.figure(figsize=(12,6))

plt.plot(df['Beer'], label='Beer production', color='red')

plt.title('Monthly beer production in Australy')

plt.show()

# %% [markdown]
# ### Movendo valores em uma posição para se variável alvo

# %%
df['Target'] = df['Beer'].shift(-1)
df = df.dropna()

df.head()
# Out:
#             Beer  Target
# Month
# 1956-01-01  93.2    96.0
# 1956-02-01  96.0    95.2
# 1956-03-01  95.2    77.1
# 1956-04-01  77.1    70.9
# 1956-05-01  70.9    64.8

# %% [markdown]
# ### Separando treino e teste

# %%
train_size = int(len(df)*0.75)
train = df[:train_size]
test = df[train_size:]

X_train, X_test = train['Beer'].to_numpy().reshape(-1,1), test['Beer'].to_numpy().reshape(-1,1)
y_train, y_test = train['Target'].to_numpy().reshape(-1,1), test['Target'].to_numpy()

# %% [markdown]
# ### Criando modelo de regressão linear

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr_fit = lr.fit(X_train, y_train)

# %%
lr_pred = lr_fit.predict(X_test)

# %%
df_res = pd.DataFrame()
df_res['Real'] = y_test
df_res['Pred'] = lr_pred

# %%
df_res.head()
# Out:
#     Real        Pred
# 0  181.6  174.731970
# 1  182.0  175.076707
# 2  190.0  181.971448
# 3  161.2  157.150381
# 4  155.5  152.237879

# %%
plt.plot(df_res)
# Out:
# [<matplotlib.lines.Line2D at 0x25ea3c9b648>,
#  <matplotlib.lines.Line2D at 0x25ea3c7c2c8>]

# %%
lr_sc = lr.score(X_test, y_test.reshape(-1,1))
